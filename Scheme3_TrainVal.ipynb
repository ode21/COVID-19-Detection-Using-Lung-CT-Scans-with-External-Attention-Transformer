# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_path = '/content/drive/My Drive/TA_OmarDhani/'

with open(base_path + 'X_train.pickle', 'rb') as f:
    X_train = pickle.load(f)

with open(base_path + 'X_val.pickle', 'rb') as f:
    X_val = pickle.load(f)

with open(base_path + 'X_test.pickle', 'rb') as f:
    X_test = pickle.load(f)

with open(base_path + 'y_train.pickle', 'rb') as f:
    y_train = pickle.load(f)

with open(base_path + 'y_val.pickle', 'rb') as f:
    y_val = pickle.load(f)

with open(base_path + 'y_test.pickle', 'rb') as f:
    y_test = pickle.load(f)

# %%
# Convert grayscale images to RGB by repeating the single channel three times
X_train_rgb = np.repeat(X_train, 3, axis=-1)
X_val_rgb = np.repeat(X_val, 3, axis=-1)
X_test_rgb = np.repeat(X_test, 3, axis=-1)

# %%
# Ensure data is in numpy array format
X_train_rgb = np.array(X_train_rgb)
X_val_rgb = np.array(X_val_rgb)
X_test_rgb = np.array(X_test_rgb)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %%
# One-hot encode the labels
num_classes = 2
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
input_shape = (128, 128, 3)  # Adjusted for RGB images

weight_decay = 0.0001
learning_rate = 0.001
label_smoothing = 0.1
batch_size = 128
num_epochs = 100
patch_size = 4  # Size of the patches to be extracted from the input images.
embedding_dim = 64  # Number of hidden units.
mlp_dim = 64
num_heads = 4
attention_dropout = 0.1
projection_dropout = 0.1
num_transformer_blocks = 8

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.2),
        layers.RandomContrast(factor=0.2),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)

data_augmentation.layers[0].adapt(X_train_rgb)

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, x):
        batch_size, height, width, channels = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2], tf.shape(x)[3]
        patches = tf.image.extract_patches(
            images=x,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding='VALID',
        )
        patches = tf.reshape(patches, [batch_size, -1, self.patch_size * self.patch_size * channels])
        return patches

# %%
class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(positions)

# %%
class ExternalAttention(layers.Layer):
    def __init__(self, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.num_heads = num_heads * dim_coefficient
        self.dim_coefficient = dim_coefficient
        self.attention_dropout = attention_dropout
        self.projection_dropout = projection_dropout

        self.dense1 = layers.Dense(self.dim * self.dim_coefficient)
        self.dense2 = layers.Dense(self.dim // self.dim_coefficient)
        self.dense3 = layers.Dense(self.dim * self.dim_coefficient // self.num_heads)
        self.dense4 = layers.Dense(self.dim)
        self.softmax = layers.Softmax(axis=2)
        self.dropout1 = layers.Dropout(self.attention_dropout)
        self.dropout2 = layers.Dropout(self.projection_dropout)

    def call(self, x):
        batch_size, num_patch, channels = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]
        x = self.dense1(x)
        x = tf.reshape(x, [batch_size, num_patch, self.num_heads, self.dim * self.dim_coefficient // self.num_heads])
        x = tf.transpose(x, perm=[0, 2, 1, 3])
        attn = self.dense2(x)
        attn = self.softmax(attn)
        attn = tf.keras.layers.Lambda(lambda attn: attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True)))(attn)
        attn = self.dropout1(attn)
        x = self.dense3(attn)
        x = tf.transpose(x, perm=[0, 2, 1, 3])
        x = tf.reshape(x, [batch_size, num_patch, self.dim * self.dim_coefficient])
        x = self.dense4(x)
        x = self.dropout2(x)
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
def transformer_encoder(x, embed_dim, num_heads, mlp_dim, dropout, attention_type="self_attention"):
    # Normalization and Attention Mechanism
    x1 = layers.LayerNormalization(epsilon=1e-6)(x)
    if attention_type == "external_attention":
        attention_output = ExternalAttention(
            dim=embed_dim, num_heads=num_heads, attention_dropout=dropout, projection_dropout=dropout
        )(x1)
    else:
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=dropout
        )(x1, x1)

    # Skip connection
    x2 = layers.Add()([attention_output, x])

    # Normalization and MLP
    x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
    x3 = mlp(x3, hidden_units=[mlp_dim, embed_dim], dropout_rate=dropout)

    # Skip connection
    return layers.Add()([x3, x2])

# %%
def create_eat_classifier():
    inputs = keras.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = PatchExtract(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEmbedding((input_shape[0] // patch_size) ** 2, embedding_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(num_transformer_blocks):
        encoded_patches = transformer_encoder(
            encoded_patches, embedding_dim, num_heads, mlp_dim, attention_dropout, attention_type="external_attention"
        )

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.3)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=[2048, 1024], dropout_rate=0.3)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = keras.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=label_smoothing),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
        ],
    )

    checkpoint_filepath = "/content/drive/My Drive/TA_OmarDhani/checkpoint_Scheme3_trainval.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        X_train_rgb,
        y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(X_val_rgb, y_val),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy = model.evaluate(X_test_rgb, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history

# Function to save history
def save_history(history, history_directory, history_filename):
    history_path = os.path.join(history_directory, history_filename)
    with open(history_path, 'wb') as f:
        pickle.dump(history.history, f)

# Function to load history
def load_history(history_directory, history_filename):
    history_path = os.path.join(history_directory, history_filename)
    with open(history_path, 'rb') as f:
        return pickle.load(f)

eat_classifier = create_eat_classifier()
history = run_experiment(eat_classifier)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 64s 3s/step - accuracy: 0.5043 - loss: 53.2870 - val_accuracy: 0.5566 - val_loss: 2.7535
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.5593 - loss: 2.3327 - val_accuracy: 0.6084 - val_loss: 0.9139
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.5931 - loss: 1.6026 - val_accuracy: 0.5221 - val_loss: 1.6054
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5593 - loss: 1.2503 - val_accuracy: 0.5739 - val_loss: 0.9396
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6015 - loss: 0.8152 - val_accuracy: 0.5413 - val_loss: 1.1265
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6540 - loss: 0.7341 - val_accuracy: 0.5547 - val_loss: 0.7790
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6530 - loss: 0.7246 - val_accuracy: 0.5489 - val_loss: 0.8815
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.6471 - loss: 0.7102 - val_accuracy: 0.7313 - val_loss: 0.5840
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.6741 - loss: 0.6699 - val_accuracy: 0.7179 - val_loss: 0.5924
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6632 - loss: 0.6731 - val_accuracy: 0.7044 - val_loss: 0.6054
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6752 - loss: 0.6318 - val_accuracy: 0.7063 - val_loss: 0.5924
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6865 - loss: 0.6103 - val_accuracy: 0.7121 - val_loss: 0.5809
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7014 - loss: 0.6099 - val_accuracy: 0.7159 - val_loss: 0.6008
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6850 - loss: 0.6299 - val_accuracy: 0.7159 - val_loss: 0.5697
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6840 - loss: 0.6111 - val_accuracy: 0.7236 - val_loss: 0.5445
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7085 - loss: 0.6128 - val_accuracy: 0.6833 - val_loss: 0.5835
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6985 - loss: 0.6131 - val_accuracy: 0.7121 - val_loss: 0.5817
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6999 - loss: 0.6089 - val_accuracy: 0.7102 - val_loss: 0.5902
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6807 - loss: 0.6123 - val_accuracy: 0.7006 - val_loss: 0.5848
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6977 - loss: 0.5975 - val_accuracy: 0.6910 - val_loss: 0.5869
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.7243 - loss: 0.5707 - val_accuracy: 0.7486 - val_loss: 0.5466
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.7089 - loss: 0.6004 - val_accuracy: 0.7658 - val_loss: 0.5620
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7028 - loss: 0.6000 - val_accuracy: 0.7332 - val_loss: 0.5753
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7055 - loss: 0.5866 - val_accuracy: 0.7121 - val_loss: 0.5693
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7213 - loss: 0.5940 - val_accuracy: 0.7159 - val_loss: 0.5738
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7165 - loss: 0.5943 - val_accuracy: 0.7466 - val_loss: 0.5685
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7056 - loss: 0.5805 - val_accuracy: 0.7658 - val_loss: 0.5478
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7628 - loss: 0.5347 - val_accuracy: 0.7198 - val_loss: 0.5697
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7484 - loss: 0.5241 - val_accuracy: 0.7217 - val_loss: 0.5713
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7801 - loss: 0.5198 - val_accuracy: 0.7409 - val_loss: 0.5652
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7875 - loss: 0.5086 - val_accuracy: 0.6756 - val_loss: 0.6024
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7808 - loss: 0.5297 - val_accuracy: 0.7083 - val_loss: 0.5942
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7544 - loss: 0.5638 - val_accuracy: 0.6564 - val_loss: 0.6392
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7577 - loss: 0.5426 - val_accuracy: 0.7217 - val_loss: 0.5752
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7778 - loss: 0.5158 - val_accuracy: 0.6583 - val_loss: 0.6007
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7504 - loss: 0.5543 - val_accuracy: 0.7217 - val_loss: 0.5608
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7239 - loss: 0.5626 - val_accuracy: 0.7294 - val_loss: 0.5576
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7703 - loss: 0.5272 - val_accuracy: 0.6987 - val_loss: 0.5852
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7872 - loss: 0.5107 - val_accuracy: 0.7025 - val_loss: 0.5851
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7673 - loss: 0.5324 - val_accuracy: 0.7044 - val_loss: 0.5796
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7567 - loss: 0.5323 - val_accuracy: 0.7697 - val_loss: 0.5413
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7461 - loss: 0.5782 - val_accuracy: 0.6276 - val_loss: 0.6206
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7768 - loss: 0.5303 - val_accuracy: 0.6603 - val_loss: 0.6160
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7534 - loss: 0.5393 - val_accuracy: 0.7370 - val_loss: 0.5554
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 44s 5s/step - accuracy: 0.7711 - loss: 0.5256 - val_accuracy: 0.7927 - val_loss: 0.5404
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.7463 - loss: 0.5589 - val_accuracy: 0.7889 - val_loss: 0.5234
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7796 - loss: 0.5281 - val_accuracy: 0.5720 - val_loss: 0.7658
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7319 - loss: 0.5742 - val_accuracy: 0.6603 - val_loss: 0.6066
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7668 - loss: 0.5382 - val_accuracy: 0.7198 - val_loss: 0.5512
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7840 - loss: 0.5168 - val_accuracy: 0.7658 - val_loss: 0.5428
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7532 - loss: 0.5573 - val_accuracy: 0.6718 - val_loss: 0.5806
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7489 - loss: 0.5474 - val_accuracy: 0.6392 - val_loss: 0.6130
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7847 - loss: 0.5224 - val_accuracy: 0.5528 - val_loss: 0.7817
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7768 - loss: 0.5238 - val_accuracy: 0.6315 - val_loss: 0.6314
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7739 - loss: 0.5333 - val_accuracy: 0.5624 - val_loss: 0.7509
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7771 - loss: 0.5206 - val_accuracy: 0.6084 - val_loss: 0.7164
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7833 - loss: 0.5191 - val_accuracy: 0.6008 - val_loss: 0.6915
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.7602 - loss: 0.5402
# Test accuracy: 77.85%

# %%
# Save the history
history_directory = "/content/drive/My Drive/TA_OmarDhani/"
history_filename = "history_Scheme3_trainval.pkl"
save_history(history, history_directory, history_filename)

# %%
def plot_history(history):
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Train Accuracy')
    plt.plot(history['val_accuracy'], label='Validation Accuracy')
    plt.title('Train and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Validation Loss')
    plt.title('Train and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()

    plt.show()

# %%
# Load the history and plot
loaded_history = load_history(history_directory, history_filename)
plot_history(loaded_history)

# %%
# Get predictions for training and validation sets
y_train_pred = eat_classifier.predict(X_train_rgb)
y_val_pred = eat_classifier.predict(X_val_rgb)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step

# %%
# Convert predictions to class labels
y_train_pred_classes = np.argmax(y_train_pred, axis=1)
y_val_pred_classes = np.argmax(y_val_pred, axis=1)
y_train_true_classes = np.argmax(y_train, axis=1)
y_val_true_classes = np.argmax(y_val, axis=1)

# %%
# Generate confusion matrix for training set
conf_matrix_train = confusion_matrix(y_train_true_classes, y_train_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix - Training Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Generate confusion matrix for validation set
conf_matrix_val = confusion_matrix(y_val_true_classes, y_val_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_val, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix - Validation Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
