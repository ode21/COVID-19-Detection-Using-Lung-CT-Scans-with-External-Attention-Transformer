# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping

# %%
base_path = '/content/drive/My Drive/TA_OmarDhani/'

with open(base_path + 'X_train.pickle', 'rb') as f:
    X_train = pickle.load(f)

with open(base_path + 'X_val.pickle', 'rb') as f:
    X_val = pickle.load(f)

with open(base_path + 'X_test.pickle', 'rb') as f:
    X_test = pickle.load(f)

with open(base_path + 'y_train.pickle', 'rb') as f:
    y_train = pickle.load(f)

with open(base_path + 'y_val.pickle', 'rb') as f:
    y_val = pickle.load(f)

with open(base_path + 'y_test.pickle', 'rb') as f:
    y_test = pickle.load(f)

# %%
# Convert grayscale images to RGB by repeating the single channel three times
X_train_rgb = np.repeat(X_train, 3, axis=-1)
X_val_rgb = np.repeat(X_val, 3, axis=-1)
X_test_rgb = np.repeat(X_test, 3, axis=-1)

# %%
# Ensure data is in numpy array format
X_train_rgb = np.array(X_train_rgb)
X_val_rgb = np.array(X_val_rgb)
X_test_rgb = np.array(X_test_rgb)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %%
# One-hot encode the labels
num_classes = 2
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
input_shape = (128, 128, 3)  # Adjusted for RGB images

weight_decay = 0.0001
learning_rate = 0.001
label_smoothing = 0.1
batch_size = 128
num_epochs = 100
patch_size = 8  # Size of the patches to be extracted from the input images.
embedding_dim = 64  # Number of hidden units.
mlp_dim = 64
num_heads = 4
attention_dropout = 0.1
projection_dropout = 0.1
num_transformer_blocks = 8

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.2),
        layers.RandomContrast(factor=0.2),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)

data_augmentation.layers[0].adapt(X_train_rgb)

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, x):
        batch_size, height, width, channels = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2], tf.shape(x)[3]
        patches = tf.image.extract_patches(
            images=x,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding='VALID',
        )
        patches = tf.reshape(patches, [batch_size, -1, self.patch_size * self.patch_size * channels])
        return patches

class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(positions)

# %%
class ExternalAttention(layers.Layer):
    def __init__(self, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.num_heads = num_heads * dim_coefficient
        self.dim_coefficient = dim_coefficient
        self.attention_dropout = attention_dropout
        self.projection_dropout = projection_dropout

        self.dense1 = layers.Dense(self.dim * self.dim_coefficient)
        self.dense2 = layers.Dense(self.dim // self.dim_coefficient)
        self.dense3 = layers.Dense(self.dim * self.dim_coefficient // self.num_heads)
        self.dense4 = layers.Dense(self.dim)
        self.softmax = layers.Softmax(axis=2)
        self.dropout1 = layers.Dropout(self.attention_dropout)
        self.dropout2 = layers.Dropout(self.projection_dropout)

    def call(self, x):
        batch_size, num_patch, channels = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]
        x = self.dense1(x)
        x = tf.reshape(x, [batch_size, num_patch, self.num_heads, self.dim * self.dim_coefficient // self.num_heads])
        x = tf.transpose(x, perm=[0, 2, 1, 3])
        attn = self.dense2(x)
        attn = self.softmax(attn)
        attn = tf.keras.layers.Lambda(lambda attn: attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True)))(attn)
        attn = self.dropout1(attn)
        x = self.dense3(attn)
        x = tf.transpose(x, perm=[0, 2, 1, 3])
        x = tf.reshape(x, [batch_size, num_patch, self.dim * self.dim_coefficient])
        x = self.dense4(x)
        x = self.dropout2(x)
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
def transformer_encoder(x, embed_dim, num_heads, mlp_dim, dropout, attention_type="self_attention"):
    # Normalization and Attention Mechanism
    x1 = layers.LayerNormalization(epsilon=1e-6)(x)
    if attention_type == "external_attention":
        attention_output = ExternalAttention(
            dim=embed_dim, num_heads=num_heads, attention_dropout=dropout, projection_dropout=dropout
        )(x1)
    else:
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=dropout
        )(x1, x1)

    # Skip connection
    x2 = layers.Add()([attention_output, x])

    # Normalization and MLP
    x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
    x3 = mlp(x3, hidden_units=[mlp_dim, embed_dim], dropout_rate=dropout)

    # Skip connection
    return layers.Add()([x3, x2])

# %%
def create_eat_classifier():
    inputs = keras.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = PatchExtract(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEmbedding((input_shape[0] // patch_size) ** 2, embedding_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(num_transformer_blocks):
        encoded_patches = transformer_encoder(
            encoded_patches, embedding_dim, num_heads, mlp_dim, attention_dropout, attention_type="external_attention"
        )

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.3)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=[2048, 1024], dropout_rate=0.3)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = keras.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=label_smoothing),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
        ],
    )

    checkpoint_filepath = "/content/drive/My Drive/TA_OmarDhani/checkpoint_Scheme_4.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        X_train_rgb,
        y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(X_val_rgb, y_val),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy = model.evaluate(X_test_rgb, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history

# Function to save history
def save_history(history, history_directory, history_filename):
    history_path = os.path.join(history_directory, history_filename)
    with open(history_path, 'wb') as f:
        pickle.dump(history.history, f)

# Function to load history
def load_history(history_directory, history_filename):
    history_path = os.path.join(history_directory, history_filename)
    with open(history_path, 'rb') as f:
        return pickle.load(f)

eat_classifier = create_eat_classifier()
history = run_experiment(eat_classifier)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 487ms/step - accuracy: 0.5045 - loss: 14.9806 - val_accuracy: 0.4299 - val_loss: 1.7075
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step - accuracy: 0.5483 - loss: 0.9843 - val_accuracy: 0.4530 - val_loss: 1.8664
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 329ms/step - accuracy: 0.6309 - loss: 0.7297 - val_accuracy: 0.4549 - val_loss: 2.2991
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 331ms/step - accuracy: 0.6310 - loss: 0.6662 - val_accuracy: 0.5489 - val_loss: 2.1178
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step - accuracy: 0.5885 - loss: 0.7064 - val_accuracy: 0.5797 - val_loss: 1.5822
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 334ms/step - accuracy: 0.6505 - loss: 0.6492 - val_accuracy: 0.5969 - val_loss: 1.4209
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.6559 - loss: 0.6442 - val_accuracy: 0.5969 - val_loss: 1.0913
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 332ms/step - accuracy: 0.6602 - loss: 0.6238 - val_accuracy: 0.6257 - val_loss: 0.9181
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6602 - loss: 0.6561 - val_accuracy: 0.6180 - val_loss: 1.0055
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.6948 - loss: 0.6016 - val_accuracy: 0.6027 - val_loss: 0.9946
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.6894 - loss: 0.6074 - val_accuracy: 0.6008 - val_loss: 0.9353
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 326ms/step - accuracy: 0.7042 - loss: 0.5965 - val_accuracy: 0.6392 - val_loss: 0.8656
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step - accuracy: 0.7029 - loss: 0.5990 - val_accuracy: 0.6488 - val_loss: 0.8476
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7094 - loss: 0.5917 - val_accuracy: 0.6065 - val_loss: 0.9498
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7253 - loss: 0.5772 - val_accuracy: 0.6200 - val_loss: 0.9184
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step - accuracy: 0.7344 - loss: 0.5586 - val_accuracy: 0.6699 - val_loss: 0.8487
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7219 - loss: 0.5710 - val_accuracy: 0.6526 - val_loss: 0.8430
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step - accuracy: 0.7637 - loss: 0.5483 - val_accuracy: 0.6910 - val_loss: 0.7798
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7135 - loss: 0.5800 - val_accuracy: 0.6833 - val_loss: 0.7566
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7308 - loss: 0.5716 - val_accuracy: 0.6660 - val_loss: 0.7909
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7239 - loss: 0.5661 - val_accuracy: 0.6814 - val_loss: 0.7962
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7379 - loss: 0.5548 - val_accuracy: 0.6392 - val_loss: 0.9113
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7803 - loss: 0.5271 - val_accuracy: 0.6583 - val_loss: 0.9038
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7136 - loss: 0.5856 - val_accuracy: 0.6814 - val_loss: 0.7881
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step - accuracy: 0.7617 - loss: 0.5452 - val_accuracy: 0.7102 - val_loss: 0.7304
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7398 - loss: 0.5585 - val_accuracy: 0.6948 - val_loss: 0.6681
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7777 - loss: 0.5117 - val_accuracy: 0.7121 - val_loss: 0.6300
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7880 - loss: 0.5153 - val_accuracy: 0.6852 - val_loss: 0.6484
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7776 - loss: 0.5175 - val_accuracy: 0.7274 - val_loss: 0.6091
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.7999 - loss: 0.4958 - val_accuracy: 0.7351 - val_loss: 0.6029
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7987 - loss: 0.5044 - val_accuracy: 0.7006 - val_loss: 0.6305
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7682 - loss: 0.5167 - val_accuracy: 0.7217 - val_loss: 0.5932
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.8017 - loss: 0.4971 - val_accuracy: 0.6910 - val_loss: 0.6508
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.7753 - loss: 0.5217 - val_accuracy: 0.6910 - val_loss: 0.6243
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7510 - loss: 0.5361 - val_accuracy: 0.7044 - val_loss: 0.6086
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7801 - loss: 0.5085 - val_accuracy: 0.6775 - val_loss: 0.6058
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.8002 - loss: 0.4851 - val_accuracy: 0.7044 - val_loss: 0.6868
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7898 - loss: 0.5039 - val_accuracy: 0.6603 - val_loss: 0.6635
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.8028 - loss: 0.5072 - val_accuracy: 0.6315 - val_loss: 0.6483
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7676 - loss: 0.5320 - val_accuracy: 0.6180 - val_loss: 0.6224
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7316 - loss: 0.5599 - val_accuracy: 0.7524 - val_loss: 0.5910
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 721ms/step - accuracy: 0.7846 - loss: 0.5174 - val_accuracy: 0.7601 - val_loss: 0.5870
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7955 - loss: 0.5011 - val_accuracy: 0.7198 - val_loss: 0.6395
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7634 - loss: 0.5550 - val_accuracy: 0.7332 - val_loss: 0.5849
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7894 - loss: 0.5028 - val_accuracy: 0.7332 - val_loss: 0.6041
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7910 - loss: 0.4905 - val_accuracy: 0.7255 - val_loss: 0.5876
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7717 - loss: 0.5226 - val_accuracy: 0.7370 - val_loss: 0.5797
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7819 - loss: 0.5142 - val_accuracy: 0.7294 - val_loss: 0.6152
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.8012 - loss: 0.5053 - val_accuracy: 0.7102 - val_loss: 0.6213
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7906 - loss: 0.5074 - val_accuracy: 0.7274 - val_loss: 0.6064
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.8113 - loss: 0.4820 - val_accuracy: 0.6603 - val_loss: 0.7316
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7506 - loss: 0.5701 - val_accuracy: 0.6660 - val_loss: 0.6077
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7749 - loss: 0.5222 - val_accuracy: 0.7063 - val_loss: 0.6372
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7865 - loss: 0.5036 - val_accuracy: 0.7044 - val_loss: 0.6156
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.8056 - loss: 0.5039 - val_accuracy: 0.6987 - val_loss: 0.6211
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7967 - loss: 0.5108 - val_accuracy: 0.7063 - val_loss: 0.6257
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7841 - loss: 0.5261 - val_accuracy: 0.7025 - val_loss: 0.5857
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7750 - loss: 0.5123 - val_accuracy: 0.7044 - val_loss: 0.6040
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7918 - loss: 0.5086 - val_accuracy: 0.6814 - val_loss: 0.6181
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7335 - loss: 0.6036
# Test accuracy: 75.84%

# %%
# Save the history
history_directory = "/content/drive/My Drive/TA_OmarDhani/"
history_filename = "history_Scheme4.pkl"
save_history(history, history_directory, history_filename)

# %%
def plot_history(history):
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Train Accuracy')
    plt.plot(history['val_accuracy'], label='Validation Accuracy')
    plt.title('Train and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Validation Loss')
    plt.title('Train and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()

    plt.show()

# %%
# Load the history and plot
loaded_history = load_history(history_directory, history_filename)
plot_history(loaded_history)

# Get predictions
y_pred = eat_classifier.predict(X_test_rgb)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate classification report
print("\nClassification Report:\n")
print(classification_report(y_true_classes, y_pred_classes))
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77       369
#            1       0.79      0.71      0.75       376
#
#     accuracy                           0.76       745
#    macro avg       0.76      0.76      0.76       745
# weighted avg       0.76      0.76      0.76       745

# %%
# Generate confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
