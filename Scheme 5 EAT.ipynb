# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping

# %%
base_path = '/content/drive/My Drive/TA_OmarDhani/'

with open(base_path + 'X_train.pickle', 'rb') as f:
    X_train = pickle.load(f)

with open(base_path + 'X_val.pickle', 'rb') as f:
    X_val = pickle.load(f)

with open(base_path + 'X_test.pickle', 'rb') as f:
    X_test = pickle.load(f)

with open(base_path + 'y_train.pickle', 'rb') as f:
    y_train = pickle.load(f)

with open(base_path + 'y_val.pickle', 'rb') as f:
    y_val = pickle.load(f)

with open(base_path + 'y_test.pickle', 'rb') as f:
    y_test = pickle.load(f)

# %%
# Convert grayscale images to RGB by repeating the single channel three times
X_train_rgb = np.repeat(X_train, 3, axis=-1)
X_val_rgb = np.repeat(X_val, 3, axis=-1)
X_test_rgb = np.repeat(X_test, 3, axis=-1)

# %%
import matplotlib.pyplot as plt
import random

# Pilih sejumlah gambar secara acak dari X_train
num_images = 2
indices = random.sample(range(X_train.shape[0]), num_images)

# Plot gambar
plt.figure(figsize=(15, 6))
for i, idx in enumerate(indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[idx].reshape(128, 128), cmap='gray')  # Asumsikan gambar grayscale
    plt.title(f"Label: {np.argmax(y_train[idx])}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Ensure data is in numpy array format
X_train_rgb = np.array(X_train_rgb)
X_val_rgb = np.array(X_val_rgb)
X_test_rgb = np.array(X_test_rgb)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %%
# One-hot encode the labels
num_classes = 2
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
input_shape = (128, 128, 3)  # Adjusted for RGB images

weight_decay = 0.0001
learning_rate = 0.001
label_smoothing = 0.1
batch_size = 128
num_epochs = 100
patch_size = 8  # Size of the patches to be extracted from the input images.
embedding_dim = 64  # Number of hidden units.
mlp_dim = 64
num_heads = 8
attention_dropout = 0.1
projection_dropout = 0.1
num_transformer_blocks = 8

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.2),
        layers.RandomContrast(factor=0.2),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)

data_augmentation.layers[0].adapt(X_train_rgb)

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, x):
        batch_size, height, width, channels = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2], tf.shape(x)[3]
        patches = tf.image.extract_patches(
            images=x,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding='VALID',
        )
        patches = tf.reshape(patches, [batch_size, -1, self.patch_size * self.patch_size * channels])
        return patches

class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(positions)

# %%
class ExternalAttention(layers.Layer):
    def __init__(self, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.num_heads = num_heads * dim_coefficient
        self.dim_coefficient = dim_coefficient
        self.attention_dropout = attention_dropout
        self.projection_dropout = projection_dropout

        self.dense1 = layers.Dense(self.dim * self.dim_coefficient)
        self.dense2 = layers.Dense(self.dim // self.dim_coefficient)
        self.dense3 = layers.Dense(self.dim * self.dim_coefficient // self.num_heads)
        self.dense4 = layers.Dense(self.dim)
        self.softmax = layers.Softmax(axis=2)
        self.dropout1 = layers.Dropout(self.attention_dropout)
        self.dropout2 = layers.Dropout(self.projection_dropout)

    def call(self, x):
        batch_size, num_patch, channels = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]
        x = self.dense1(x)
        x = tf.reshape(x, [batch_size, num_patch, self.num_heads, self.dim * self.dim_coefficient // self.num_heads])
        x = tf.transpose(x, perm=[0, 2, 1, 3])
        attn = self.dense2(x)
        attn = self.softmax(attn)
        attn = tf.keras.layers.Lambda(lambda attn: attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True)))(attn)
        attn = self.dropout1(attn)
        x = self.dense3(attn)
        x = tf.transpose(x, perm=[0, 2, 1, 3])
        x = tf.reshape(x, [batch_size, num_patch, self.dim * self.dim_coefficient])
        x = self.dense4(x)
        x = self.dropout2(x)
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
def transformer_encoder(x, embed_dim, num_heads, mlp_dim, dropout, attention_type="self_attention"):
    # Normalization and Attention Mechanism
    x1 = layers.LayerNormalization(epsilon=1e-6)(x)
    if attention_type == "external_attention":
        attention_output = ExternalAttention(
            dim=embed_dim, num_heads=num_heads, attention_dropout=dropout, projection_dropout=dropout
        )(x1)
    else:
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=dropout
        )(x1, x1)

    # Skip connection
    x2 = layers.Add()([attention_output, x])

    # Normalization and MLP
    x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
    x3 = mlp(x3, hidden_units=[mlp_dim, embed_dim], dropout_rate=dropout)

    # Skip connection
    return layers.Add()([x3, x2])

# %%
def create_eat_classifier():
    inputs = keras.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = PatchExtract(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEmbedding((input_shape[0] // patch_size) ** 2, embedding_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(num_transformer_blocks):
        encoded_patches = transformer_encoder(
            encoded_patches, embedding_dim, num_heads, mlp_dim, attention_dropout, attention_type="external_attention"
        )

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.3)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=[2048, 1024], dropout_rate=0.3)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = keras.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=label_smoothing),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
        ],
    )

    checkpoint_filepath = "/content/drive/My Drive/TA_OmarDhani/checkpoint_Scheme_5.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        X_train_rgb,
        y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(X_val_rgb, y_val),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy = model.evaluate(X_test_rgb, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history

# Function to save history
def save_history(history, history_directory, history_filename):
    history_path = os.path.join(history_directory, history_filename)
    with open(history_path, 'wb') as f:
        pickle.dump(history.history, f)

# Function to load history
def load_history(history_directory, history_filename):
    history_path = os.path.join(history_directory, history_filename)
    with open(history_path, 'rb') as f:
        return pickle.load(f)

eat_classifier = create_eat_classifier()
history = run_experiment(eat_classifier)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.4900 - loss: 53.9138 - val_accuracy: 0.5585 - val_loss: 3.1767
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.5898 - loss: 2.1987 - val_accuracy: 0.6603 - val_loss: 1.2727
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.5924 - loss: 1.7618 - val_accuracy: 0.5797 - val_loss: 1.6221
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.5838 - loss: 1.2271 - val_accuracy: 0.6084 - val_loss: 0.8255
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 392ms/step - accuracy: 0.6230 - loss: 0.9034 - val_accuracy: 0.6296 - val_loss: 0.8241
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 392ms/step - accuracy: 0.5920 - loss: 0.8178 - val_accuracy: 0.5777 - val_loss: 0.6826
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 393ms/step - accuracy: 0.6042 - loss: 0.7084 - val_accuracy: 0.5701 - val_loss: 0.6940
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 393ms/step - accuracy: 0.6301 - loss: 0.6908 - val_accuracy: 0.6046 - val_loss: 0.6444
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.6581 - loss: 0.6490 - val_accuracy: 0.6583 - val_loss: 0.6266
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 394ms/step - accuracy: 0.6634 - loss: 0.6408 - val_accuracy: 0.6238 - val_loss: 0.6484
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 393ms/step - accuracy: 0.6768 - loss: 0.6138 - val_accuracy: 0.6334 - val_loss: 0.6571
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 392ms/step - accuracy: 0.6814 - loss: 0.6227 - val_accuracy: 0.6507 - val_loss: 0.6457
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 397ms/step - accuracy: 0.7005 - loss: 0.5963 - val_accuracy: 0.5931 - val_loss: 0.6926
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.6935 - loss: 0.6145 - val_accuracy: 0.5681 - val_loss: 0.7336
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.6874 - loss: 0.6084 - val_accuracy: 0.5758 - val_loss: 0.6970
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.6910 - loss: 0.6027 - val_accuracy: 0.6123 - val_loss: 0.6907
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.6973 - loss: 0.6058 - val_accuracy: 0.6296 - val_loss: 0.6586
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7061 - loss: 0.5946 - val_accuracy: 0.5912 - val_loss: 0.7151
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7170 - loss: 0.5881 - val_accuracy: 0.5950 - val_loss: 0.7106
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 392ms/step - accuracy: 0.7038 - loss: 0.5935 - val_accuracy: 0.5988 - val_loss: 0.6982
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7128 - loss: 0.5798 - val_accuracy: 0.5643 - val_loss: 0.7144
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7080 - loss: 0.5889 - val_accuracy: 0.5489 - val_loss: 0.7155
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 393ms/step - accuracy: 0.7087 - loss: 0.5878 - val_accuracy: 0.5470 - val_loss: 0.7497
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7603 - loss: 0.5579 - val_accuracy: 0.5509 - val_loss: 0.7523
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7499 - loss: 0.5443 - val_accuracy: 0.5816 - val_loss: 0.7567
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7867 - loss: 0.5139 - val_accuracy: 0.5624 - val_loss: 0.9966
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7606 - loss: 0.5334 - val_accuracy: 0.5489 - val_loss: 1.0928
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7590 - loss: 0.5562 - val_accuracy: 0.5451 - val_loss: 1.0016
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 396ms/step - accuracy: 0.7190 - loss: 0.5664 - val_accuracy: 0.6084 - val_loss: 0.7002
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7462 - loss: 0.5447 - val_accuracy: 0.5912 - val_loss: 0.7632
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7485 - loss: 0.5425 - val_accuracy: 0.6641 - val_loss: 0.6537
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7233 - loss: 0.5797 - val_accuracy: 0.5720 - val_loss: 0.7487
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 392ms/step - accuracy: 0.7652 - loss: 0.5426 - val_accuracy: 0.5451 - val_loss: 1.0214
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 389ms/step - accuracy: 0.7695 - loss: 0.5369 - val_accuracy: 0.5758 - val_loss: 0.7069
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7712 - loss: 0.5241 - val_accuracy: 0.5681 - val_loss: 0.8148
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7880 - loss: 0.5246 - val_accuracy: 0.5681 - val_loss: 0.8940
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7937 - loss: 0.5000 - val_accuracy: 0.5969 - val_loss: 0.7907
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7635 - loss: 0.5417 - val_accuracy: 0.5681 - val_loss: 0.7458
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7735 - loss: 0.5425 - val_accuracy: 0.5681 - val_loss: 0.7705
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7724 - loss: 0.5343 - val_accuracy: 0.5681 - val_loss: 0.8991
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7862 - loss: 0.5093 - val_accuracy: 0.5950 - val_loss: 0.8843
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 392ms/step - accuracy: 0.7931 - loss: 0.5028 - val_accuracy: 0.6411 - val_loss: 0.7297
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.8037 - loss: 0.5028 - val_accuracy: 0.6104 - val_loss: 0.7606
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7672 - loss: 0.5407 - val_accuracy: 0.5758 - val_loss: 0.7513
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7662 - loss: 0.5185 - val_accuracy: 0.5643 - val_loss: 0.8856
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7957 - loss: 0.5106 - val_accuracy: 0.5509 - val_loss: 1.1281
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7641 - loss: 0.5656 - val_accuracy: 0.5816 - val_loss: 0.7024
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7795 - loss: 0.5186 - val_accuracy: 0.6430 - val_loss: 0.6809
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7694 - loss: 0.5332 - val_accuracy: 0.5701 - val_loss: 0.7604
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7927 - loss: 0.5160 - val_accuracy: 0.6219 - val_loss: 0.7647
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7796 - loss: 0.5160 - val_accuracy: 0.6833 - val_loss: 0.6845
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7520 - loss: 0.5333 - val_accuracy: 0.5681 - val_loss: 0.9261
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7997 - loss: 0.5020 - val_accuracy: 0.5605 - val_loss: 1.1071
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7823 - loss: 0.5315 - val_accuracy: 0.5720 - val_loss: 0.8810
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7798 - loss: 0.5220 - val_accuracy: 0.6142 - val_loss: 0.7249
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.7689 - loss: 0.5397 - val_accuracy: 0.6718 - val_loss: 0.6440
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 391ms/step - accuracy: 0.7298 - loss: 0.5543 - val_accuracy: 0.5624 - val_loss: 0.9621
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5399 - loss: 0.8520
# Test accuracy: 69.26%

# %%
# Save the history
history_directory = "/content/drive/My Drive/TA_OmarDhani/"
history_filename = "history_Scheme5.pkl"
save_history(history, history_directory, history_filename)

# %%
def plot_history(history):
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Train Accuracy')
    plt.plot(history['val_accuracy'], label='Validation Accuracy')
    plt.title('Train and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Validation Loss')
    plt.title('Train and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()

    plt.show()

# %%
# Load the history and plot
loaded_history = load_history(history_directory, history_filename)
plot_history(loaded_history)

# Get predictions
y_pred = eat_classifier.predict(X_test_rgb)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate classification report
print("\nClassification Report:\n")
print(classification_report(y_true_classes, y_pred_classes))
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.94      0.75       369
#            1       0.88      0.45      0.60       376
#
#     accuracy                           0.69       745
#    macro avg       0.75      0.69      0.67       745
# weighted avg       0.76      0.69      0.67       745

# %%
# Generate confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
