# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_path = '/content/drive/My Drive/TA_OmarDhani/'

with open(base_path + 'X_train.pickle', 'rb') as f:
    X_train = pickle.load(f)

with open(base_path + 'X_val.pickle', 'rb') as f:
    X_val = pickle.load(f)

with open(base_path + 'X_test.pickle', 'rb') as f:
    X_test = pickle.load(f)

with open(base_path + 'y_train.pickle', 'rb') as f:
    y_train = pickle.load(f)

with open(base_path + 'y_val.pickle', 'rb') as f:
    y_val = pickle.load(f)

with open(base_path + 'y_test.pickle', 'rb') as f:
    y_test = pickle.load(f)

# %%
# Convert grayscale images to RGB by repeating the single channel three times
X_train_rgb = np.repeat(X_train, 3, axis=-1)
X_val_rgb = np.repeat(X_val, 3, axis=-1)
X_test_rgb = np.repeat(X_test, 3, axis=-1)

# %%
# Ensure data is in numpy array format
X_train_rgb = np.array(X_train_rgb)
X_val_rgb = np.array(X_val_rgb)
X_test_rgb = np.array(X_test_rgb)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %%
# One-hot encode the labels
num_classes = 2
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
input_shape = (128, 128, 3)  # Adjusted for RGB images

weight_decay = 0.0001
learning_rate = 0.001
label_smoothing = 0.1
batch_size = 128
num_epochs = 100
patch_size = 4  # Size of the patches to be extracted from the input images.
embedding_dim = 64  # Number of hidden units.
mlp_dim = 128
num_heads = 4
attention_dropout = 0.1
projection_dropout = 0.1
num_transformer_blocks = 8

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.2),
        layers.RandomContrast(factor=0.2),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)

data_augmentation.layers[0].adapt(X_train_rgb)

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, x):
        batch_size, height, width, channels = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2], tf.shape(x)[3]
        patches = tf.image.extract_patches(
            images=x,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding='VALID',
        )
        patches = tf.reshape(patches, [batch_size, -1, self.patch_size * self.patch_size * channels])
        return patches

# %%
class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(positions)

# %%
class ExternalAttention(layers.Layer):
    def __init__(self, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.num_heads = num_heads * dim_coefficient
        self.dim_coefficient = dim_coefficient
        self.attention_dropout = attention_dropout
        self.projection_dropout = projection_dropout

        self.dense1 = layers.Dense(self.dim * self.dim_coefficient)
        self.dense2 = layers.Dense(self.dim // self.dim_coefficient)
        self.dense3 = layers.Dense(self.dim * self.dim_coefficient // self.num_heads)
        self.dense4 = layers.Dense(self.dim)
        self.softmax = layers.Softmax(axis=2)
        self.dropout1 = layers.Dropout(self.attention_dropout)
        self.dropout2 = layers.Dropout(self.projection_dropout)

    def call(self, x):
        batch_size, num_patch, channels = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]
        x = self.dense1(x)
        x = tf.reshape(x, [batch_size, num_patch, self.num_heads, self.dim * self.dim_coefficient // self.num_heads])
        x = tf.transpose(x, perm=[0, 2, 1, 3])
        attn = self.dense2(x)
        attn = self.softmax(attn)
        attn = tf.keras.layers.Lambda(lambda attn: attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True)))(attn)
        attn = self.dropout1(attn)
        x = self.dense3(attn)
        x = tf.transpose(x, perm=[0, 2, 1, 3])
        x = tf.reshape(x, [batch_size, num_patch, self.dim * self.dim_coefficient])
        x = self.dense4(x)
        x = self.dropout2(x)
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
def transformer_encoder(x, embed_dim, num_heads, mlp_dim, dropout, attention_type="self_attention"):
    # Normalization and Attention Mechanism
    x1 = layers.LayerNormalization(epsilon=1e-6)(x)
    if attention_type == "external_attention":
        attention_output = ExternalAttention(
            dim=embed_dim, num_heads=num_heads, attention_dropout=dropout, projection_dropout=dropout
        )(x1)
    else:
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=dropout
        )(x1, x1)

    # Skip connection
    x2 = layers.Add()([attention_output, x])

    # Normalization and MLP
    x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
    x3 = mlp(x3, hidden_units=[mlp_dim, embed_dim], dropout_rate=dropout)

    # Skip connection
    return layers.Add()([x3, x2])

# %%
def create_eat_classifier():
    inputs = keras.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = PatchExtract(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEmbedding((input_shape[0] // patch_size) ** 2, embedding_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(num_transformer_blocks):
        encoded_patches = transformer_encoder(
            encoded_patches, embedding_dim, num_heads, mlp_dim, attention_dropout, attention_type="external_attention"
        )

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.3)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=[2048, 1024], dropout_rate=0.3)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = keras.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True, label_smoothing=label_smoothing),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
        ],
    )

    checkpoint_filepath = "/content/drive/My Drive/TA_OmarDhani/checkpoint_Scheme2_trainval.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        X_train_rgb,
        y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(X_val_rgb, y_val),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy = model.evaluate(X_test_rgb, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history

# Function to save history
def save_history(history, history_directory, history_filename):
    history_path = os.path.join(history_directory, history_filename)
    with open(history_path, 'wb') as f:
        pickle.dump(history.history, f)

# Function to load history
def load_history(history_directory, history_filename):
    history_path = os.path.join(history_directory, history_filename)
    with open(history_path, 'rb') as f:
        return pickle.load(f)

eat_classifier = create_eat_classifier()
history = run_experiment(eat_classifier)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.5103 - loss: 54.5587 - val_accuracy: 0.6526 - val_loss: 2.0654
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 853ms/step - accuracy: 0.5445 - loss: 2.7707 - val_accuracy: 0.6142 - val_loss: 2.8321
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 854ms/step - accuracy: 0.5835 - loss: 1.2801 - val_accuracy: 0.6238 - val_loss: 2.1682
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 854ms/step - accuracy: 0.6034 - loss: 1.0951 - val_accuracy: 0.6257 - val_loss: 2.7868
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 853ms/step - accuracy: 0.6442 - loss: 0.8979 - val_accuracy: 0.6238 - val_loss: 2.6823
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.6033 - loss: 0.8462 - val_accuracy: 0.6583 - val_loss: 1.5521
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 854ms/step - accuracy: 0.6135 - loss: 0.7821 - val_accuracy: 0.6372 - val_loss: 1.5750
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 854ms/step - accuracy: 0.6362 - loss: 0.7120 - val_accuracy: 0.6219 - val_loss: 1.9897
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.6260 - loss: 0.7494 - val_accuracy: 0.6583 - val_loss: 2.5220
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.6216 - loss: 0.7242 - val_accuracy: 0.6488 - val_loss: 1.6140
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.6400 - loss: 0.6953 - val_accuracy: 0.6507 - val_loss: 1.5459
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.6459 - loss: 0.6566 - val_accuracy: 0.6699 - val_loss: 1.9699
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6823 - loss: 0.6230 - val_accuracy: 0.6871 - val_loss: 1.6742
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.6616 - loss: 0.6480 - val_accuracy: 0.6737 - val_loss: 1.4764
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 857ms/step - accuracy: 0.6540 - loss: 0.6245 - val_accuracy: 0.6699 - val_loss: 1.6501
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.6687 - loss: 0.6246 - val_accuracy: 0.6795 - val_loss: 2.1518
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.6886 - loss: 0.6092 - val_accuracy: 0.6814 - val_loss: 1.8711
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.6899 - loss: 0.6096 - val_accuracy: 0.6891 - val_loss: 1.5253
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.7054 - loss: 0.6024 - val_accuracy: 0.7006 - val_loss: 1.4994
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.6833 - loss: 0.6148 - val_accuracy: 0.6891 - val_loss: 1.8223
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7239 - loss: 0.5954 - val_accuracy: 0.7006 - val_loss: 2.0348
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 857ms/step - accuracy: 0.6816 - loss: 0.6246 - val_accuracy: 0.6987 - val_loss: 2.0692
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.6813 - loss: 0.5925 - val_accuracy: 0.6891 - val_loss: 2.7259
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.6740 - loss: 0.6182 - val_accuracy: 0.6833 - val_loss: 2.3743
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7131 - loss: 0.6017 - val_accuracy: 0.6814 - val_loss: 3.5970
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7154 - loss: 0.5878 - val_accuracy: 0.6699 - val_loss: 4.1020
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.6745 - loss: 0.6108 - val_accuracy: 0.7083 - val_loss: 1.8589
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7048 - loss: 0.5859 - val_accuracy: 0.7063 - val_loss: 1.3776
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 858ms/step - accuracy: 0.6897 - loss: 0.5964 - val_accuracy: 0.7063 - val_loss: 1.8909
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7245 - loss: 0.5720 - val_accuracy: 0.6775 - val_loss: 3.0596
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7103 - loss: 0.5906 - val_accuracy: 0.6795 - val_loss: 2.6829
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7391 - loss: 0.5589 - val_accuracy: 0.6679 - val_loss: 3.0532
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.6954 - loss: 0.5837 - val_accuracy: 0.6987 - val_loss: 2.4373
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7325 - loss: 0.5751 - val_accuracy: 0.6756 - val_loss: 4.2793
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.6985 - loss: 0.6155 - val_accuracy: 0.6871 - val_loss: 3.7343
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7099 - loss: 0.5733 - val_accuracy: 0.7006 - val_loss: 3.2382
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7066 - loss: 0.5649 - val_accuracy: 0.7006 - val_loss: 2.2226
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7173 - loss: 0.5765 - val_accuracy: 0.6891 - val_loss: 3.3292
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7201 - loss: 0.5745 - val_accuracy: 0.6795 - val_loss: 3.0809
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7243 - loss: 0.5705 - val_accuracy: 0.6814 - val_loss: 3.2879
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7110 - loss: 0.5857 - val_accuracy: 0.7063 - val_loss: 1.8272
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.6977 - loss: 0.5847 - val_accuracy: 0.7409 - val_loss: 1.2448
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7191 - loss: 0.5742 - val_accuracy: 0.7198 - val_loss: 1.3689
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 857ms/step - accuracy: 0.7286 - loss: 0.5790 - val_accuracy: 0.6948 - val_loss: 1.3397
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 857ms/step - accuracy: 0.7099 - loss: 0.5847 - val_accuracy: 0.6891 - val_loss: 1.2430
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7469 - loss: 0.5608 - val_accuracy: 0.6987 - val_loss: 1.3463
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7311 - loss: 0.5641 - val_accuracy: 0.6910 - val_loss: 2.1044
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7336 - loss: 0.5539 - val_accuracy: 0.6775 - val_loss: 3.2573
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7370 - loss: 0.5539 - val_accuracy: 0.6641 - val_loss: 4.7473
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7573 - loss: 0.5414 - val_accuracy: 0.6392 - val_loss: 4.5813
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7659 - loss: 0.5320 - val_accuracy: 0.6411 - val_loss: 6.2885
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7367 - loss: 0.5646 - val_accuracy: 0.6545 - val_loss: 4.5142
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7357 - loss: 0.5630 - val_accuracy: 0.6775 - val_loss: 3.5086
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7509 - loss: 0.5496 - val_accuracy: 0.6507 - val_loss: 2.6532
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 854ms/step - accuracy: 0.7428 - loss: 0.5461 - val_accuracy: 0.6967 - val_loss: 1.4838
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7300 - loss: 0.5710 - val_accuracy: 0.6814 - val_loss: 2.1948
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7434 - loss: 0.5509 - val_accuracy: 0.6449 - val_loss: 3.8799
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7547 - loss: 0.5369 - val_accuracy: 0.6257 - val_loss: 6.4445
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7547 - loss: 0.5303 - val_accuracy: 0.6219 - val_loss: 5.8678
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7153 - loss: 0.5680 - val_accuracy: 0.6353 - val_loss: 3.5147
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7621 - loss: 0.5348 - val_accuracy: 0.6526 - val_loss: 4.4067
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7657 - loss: 0.5259 - val_accuracy: 0.6737 - val_loss: 3.5629
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7526 - loss: 0.5526 - val_accuracy: 0.6257 - val_loss: 2.6354
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7606 - loss: 0.5360 - val_accuracy: 0.6123 - val_loss: 4.0791
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7295 - loss: 0.5676 - val_accuracy: 0.6200 - val_loss: 3.1595
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7688 - loss: 0.5461 - val_accuracy: 0.6353 - val_loss: 2.3439
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7616 - loss: 0.5307 - val_accuracy: 0.6699 - val_loss: 2.1652
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7613 - loss: 0.5384 - val_accuracy: 0.6334 - val_loss: 2.9697
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7358 - loss: 0.5786 - val_accuracy: 0.6583 - val_loss: 2.7102
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7335 - loss: 0.5676 - val_accuracy: 0.6334 - val_loss: 3.2375
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7560 - loss: 0.5464 - val_accuracy: 0.6296 - val_loss: 5.9616
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7722 - loss: 0.5430 - val_accuracy: 0.6641 - val_loss: 4.8714
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7433 - loss: 0.5640 - val_accuracy: 0.6660 - val_loss: 2.1184
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7546 - loss: 0.5430 - val_accuracy: 0.6775 - val_loss: 1.9856
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7396 - loss: 0.5521 - val_accuracy: 0.6200 - val_loss: 3.9918
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7216 - loss: 0.5936 - val_accuracy: 0.6622 - val_loss: 2.7803
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7533 - loss: 0.5358 - val_accuracy: 0.6699 - val_loss: 2.1540
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 854ms/step - accuracy: 0.7653 - loss: 0.5202 - val_accuracy: 0.6296 - val_loss: 2.9093
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.8006 - loss: 0.5136 - val_accuracy: 0.6296 - val_loss: 2.9540
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 856ms/step - accuracy: 0.7826 - loss: 0.5261 - val_accuracy: 0.6891 - val_loss: 2.4217
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7609 - loss: 0.5375 - val_accuracy: 0.6775 - val_loss: 2.1826
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7682 - loss: 0.5264 - val_accuracy: 0.6795 - val_loss: 1.7115
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7566 - loss: 0.5336 - val_accuracy: 0.6852 - val_loss: 1.7484
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7793 - loss: 0.5204 - val_accuracy: 0.7255 - val_loss: 1.8772
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7298 - loss: 0.5486 - val_accuracy: 0.6718 - val_loss: 2.8013
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7613 - loss: 0.5508 - val_accuracy: 0.6296 - val_loss: 8.6936
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7565 - loss: 0.5466 - val_accuracy: 0.6449 - val_loss: 3.7780
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7727 - loss: 0.5306 - val_accuracy: 0.6871 - val_loss: 2.4060
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7762 - loss: 0.5146 - val_accuracy: 0.6737 - val_loss: 1.8856
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7770 - loss: 0.5260 - val_accuracy: 0.6910 - val_loss: 1.3652
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7776 - loss: 0.5246 - val_accuracy: 0.6545 - val_loss: 1.2300
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7598 - loss: 0.5354 - val_accuracy: 0.6372 - val_loss: 2.1812
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7628 - loss: 0.5373 - val_accuracy: 0.7025 - val_loss: 2.5936
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7755 - loss: 0.5247 - val_accuracy: 0.7102 - val_loss: 2.0731
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7537 - loss: 0.5433 - val_accuracy: 0.6679 - val_loss: 0.9588
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7736 - loss: 0.5269 - val_accuracy: 0.6718 - val_loss: 1.1549
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7842 - loss: 0.5106 - val_accuracy: 0.6430 - val_loss: 2.4186
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7716 - loss: 0.5398 - val_accuracy: 0.6756 - val_loss: 1.8371
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7672 - loss: 0.5227 - val_accuracy: 0.6276 - val_loss: 4.1463
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 855ms/step - accuracy: 0.7805 - loss: 0.5293 - val_accuracy: 0.6315 - val_loss: 2.9744
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6439 - loss: 1.8602
# Test accuracy: 72.62%

# %%
# Save the history
history_directory = "/content/drive/My Drive/TA_OmarDhani/"
history_filename = "history_Scheme2_trainval.pkl"
save_history(history, history_directory, history_filename)

# %%
def plot_history(history):
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Train Accuracy')
    plt.plot(history['val_accuracy'], label='Validation Accuracy')
    plt.title('Train and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Validation Loss')
    plt.title('Train and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()

    plt.show()

# %%
# Load the history and plot
loaded_history = load_history(history_directory, history_filename)
plot_history(loaded_history)

# %%
# Get predictions for training and validation sets
y_train_pred = eat_classifier.predict(X_train_rgb)
y_val_pred = eat_classifier.predict(X_val_rgb)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step

# %%
# Convert predictions to class labels
y_train_pred_classes = np.argmax(y_train_pred, axis=1)
y_val_pred_classes = np.argmax(y_val_pred, axis=1)
y_train_true_classes = np.argmax(y_train, axis=1)
y_val_true_classes = np.argmax(y_val, axis=1)

# %%
# Generate confusion matrix for training set
conf_matrix_train = confusion_matrix(y_train_true_classes, y_train_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix - Training Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Generate confusion matrix for validation set
conf_matrix_val = confusion_matrix(y_val_true_classes, y_val_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_val, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix - Validation Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
